# %% [markdown]
# Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd '/content/drive/My Drive/Colab Notebooks/c247'

from all_models import *
from all_solvers import *
from all_functions import *

import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# specific package for visualization
# !pip install livelossplot --quiet
from livelossplot import PlotLosses

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
from sklearn.model_selection import KFold
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
device = torch.device('cuda' if torch.cuda.is_available() else'cpu')
# Out:
# /content/drive/My Drive/Colab Notebooks/c247

# %% [markdown]
# Load Data

# %%
# subject data
subject = 1
X_test, y_test, X_train_valid, y_train_valid = import_data_subject(subject)

# %% [markdown]
# # DeepConv, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = DeepConv(in_channels=1, classes=4, cnn_drop=0.5, trial_length=window_width).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.0745], Training accuracy [51.18%]
# Epoch [10], Validation loss [2.4036], Validation accuracy [35.42%]
# Epoch [20], Training loss [0.7396], Training accuracy [67.00%]
# Epoch [20], Validation loss [3.7019], Validation accuracy [35.42%]
# Epoch [30], Training loss [0.5940], Training accuracy [74.46%]
# Epoch [30], Validation loss [3.9106], Validation accuracy [35.42%]
# Epoch [40], Training loss [0.4878], Training accuracy [79.70%]
# Epoch [40], Validation loss [3.8247], Validation accuracy [35.61%]
# Epoch [50], Training loss [0.3939], Training accuracy [84.61%]
# Epoch [50], Validation loss [3.7188], Validation accuracy [36.55%]
# Epoch [60], Training loss [0.3413], Training accuracy [86.92%]
# Epoch [60], Validation loss [3.5764], Validation accuracy [37.31%]
# Epoch [70], Training loss [0.2912], Training accuracy [89.71%]
# Epoch [70], Validation loss [3.5605], Validation accuracy [38.07%]
# Epoch [80], Training loss [0.2313], Training accuracy [91.87%]
# Epoch [80], Validation loss [3.3202], Validation accuracy [40.15%]
# Epoch [90], Training loss [0.1913], Training accuracy [93.51%]
# Epoch [90], Validation loss [3.2894], Validation accuracy [42.80%]
# Epoch [100], Training loss [0.1529], Training accuracy [94.71%]
# Epoch [100], Validation loss [3.1434], Validation accuracy [43.94%]
# Epoch [110], Training loss [0.1365], Training accuracy [95.09%]
# Epoch [110], Validation loss [3.0909], Validation accuracy [45.08%]
# Epoch [120], Training loss [0.1292], Training accuracy [95.96%]
# Epoch [120], Validation loss [2.7947], Validation accuracy [45.45%]
# Epoch [130], Training loss [0.1167], Training accuracy [96.49%]
# Epoch [130], Validation loss [2.6596], Validation accuracy [48.30%]
# Epoch [140], Training loss [0.0952], Training accuracy [97.64%]
# Epoch [140], Validation loss [2.7569], Validation accuracy [47.54%]
# Epoch [150], Training loss [0.0933], Training accuracy [96.87%]
# Epoch [150], Validation loss [2.6736], Validation accuracy [48.30%]
# Epoch [160], Training loss [0.0829], Training accuracy [97.74%]
# Epoch [160], Validation loss [2.3874], Validation accuracy [51.70%]
# Epoch [170], Training loss [0.0729], Training accuracy [97.88%]
# Epoch [170], Validation loss [2.4445], Validation accuracy [52.46%]
# Epoch [180], Training loss [0.0646], Training accuracy [98.36%]
# Epoch [180], Validation loss [2.4943], Validation accuracy [53.79%]
# Epoch [190], Training loss [0.0542], Training accuracy [98.61%]
# Epoch [190], Validation loss [2.3802], Validation accuracy [52.08%]
# Epoch [200], Training loss [0.0503], Training accuracy [98.80%]
# Epoch [200], Validation loss [2.3668], Validation accuracy [54.36%]
# Test accuracy [45.09%]
# Test accuracy from the best model during fold [1] is: [45.09%]
# Average test accuracy of 5-fold validation: [9.02]

# %% [markdown]
# # DeepConv2, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = DeepConv2(in_channels=1, classes=4, cnn_drop=0.5).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3328], Training accuracy [49.06%]
# Epoch [10], Validation loss [1.3933], Validation accuracy [18.75%]
# Epoch [20], Training loss [1.0717], Training accuracy [53.87%]
# Epoch [20], Validation loss [1.4404], Validation accuracy [18.75%]
# Epoch [30], Training loss [0.8895], Training accuracy [55.32%]
# Epoch [30], Validation loss [1.6361], Validation accuracy [18.75%]
# Epoch [40], Training loss [0.7854], Training accuracy [63.59%]
# Epoch [40], Validation loss [1.8607], Validation accuracy [18.75%]
# Epoch [50], Training loss [0.6938], Training accuracy [70.18%]
# Epoch [50], Validation loss [2.0772], Validation accuracy [18.75%]
# Epoch [60], Training loss [0.6255], Training accuracy [74.17%]
# Epoch [60], Validation loss [2.2409], Validation accuracy [18.75%]
# Epoch [70], Training loss [0.5323], Training accuracy [80.71%]
# Epoch [70], Validation loss [2.3355], Validation accuracy [20.45%]
# Epoch [80], Training loss [0.4451], Training accuracy [84.51%]
# Epoch [80], Validation loss [2.2757], Validation accuracy [24.24%]
# Epoch [90], Training loss [0.3635], Training accuracy [88.12%]
# Epoch [90], Validation loss [2.2608], Validation accuracy [30.87%]
# Epoch [100], Training loss [0.3220], Training accuracy [90.19%]
# Epoch [100], Validation loss [2.1300], Validation accuracy [36.74%]
# Epoch [110], Training loss [0.2861], Training accuracy [91.39%]
# Epoch [110], Validation loss [2.0691], Validation accuracy [43.94%]
# Epoch [120], Training loss [0.2408], Training accuracy [92.78%]
# Epoch [120], Validation loss [2.0306], Validation accuracy [46.21%]
# Epoch [130], Training loss [0.1993], Training accuracy [94.76%]
# Epoch [130], Validation loss [2.0079], Validation accuracy [46.59%]
# Epoch [140], Training loss [0.1845], Training accuracy [94.56%]
# Epoch [140], Validation loss [1.9444], Validation accuracy [48.30%]
# Epoch [150], Training loss [0.1582], Training accuracy [95.33%]
# Epoch [150], Validation loss [1.9939], Validation accuracy [49.05%]
# Epoch [160], Training loss [0.1466], Training accuracy [96.15%]
# Epoch [160], Validation loss [2.0039], Validation accuracy [48.11%]
# Epoch [170], Training loss [0.1165], Training accuracy [96.78%]
# Epoch [170], Validation loss [2.0851], Validation accuracy [48.30%]
# Epoch [180], Training loss [0.1002], Training accuracy [97.11%]
# Epoch [180], Validation loss [2.0647], Validation accuracy [48.86%]
# Epoch [190], Training loss [0.0945], Training accuracy [97.59%]
# Epoch [190], Validation loss [1.8867], Validation accuracy [51.89%]
# Epoch [200], Training loss [0.0856], Training accuracy [97.40%]
# Epoch [200], Validation loss [2.1103], Validation accuracy [50.76%]
# Test accuracy [42.18%]
# Test accuracy from the best model during fold [1] is: [42.18%]
# Average test accuracy of 5-fold validation: [8.44]

# %% [markdown]
# # Conv1, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = Conv1(dropout=0.5, trial_length=window_width).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3005], Training accuracy [37.28%]
# Epoch [10], Validation loss [1.5087], Validation accuracy [26.70%]
# Epoch [20], Training loss [0.9983], Training accuracy [57.58%]
# Epoch [20], Validation loss [2.1457], Validation accuracy [27.08%]
# Epoch [30], Training loss [0.7674], Training accuracy [67.24%]
# Epoch [30], Validation loss [2.4780], Validation accuracy [27.08%]
# Epoch [40], Training loss [0.6406], Training accuracy [73.02%]
# Epoch [40], Validation loss [2.7412], Validation accuracy [27.08%]
# Epoch [50], Training loss [0.5429], Training accuracy [77.92%]
# Epoch [50], Validation loss [2.8876], Validation accuracy [27.08%]
# Epoch [60], Training loss [0.4172], Training accuracy [84.42%]
# Epoch [60], Validation loss [2.7969], Validation accuracy [28.98%]
# Epoch [70], Training loss [0.3074], Training accuracy [88.99%]
# Epoch [70], Validation loss [2.5690], Validation accuracy [31.25%]
# Epoch [80], Training loss [0.2482], Training accuracy [91.01%]
# Epoch [80], Validation loss [2.2967], Validation accuracy [35.98%]
# Epoch [90], Training loss [0.2173], Training accuracy [92.35%]
# Epoch [90], Validation loss [2.1904], Validation accuracy [40.15%]
# Epoch [100], Training loss [0.1698], Training accuracy [93.70%]
# Epoch [100], Validation loss [2.0751], Validation accuracy [42.61%]
# Epoch [110], Training loss [0.1230], Training accuracy [95.67%]
# Epoch [110], Validation loss [2.1208], Validation accuracy [44.32%]
# Epoch [120], Training loss [0.1104], Training accuracy [96.30%]
# Epoch [120], Validation loss [1.9582], Validation accuracy [47.16%]
# Epoch [130], Training loss [0.0971], Training accuracy [96.97%]
# Epoch [130], Validation loss [1.8895], Validation accuracy [51.14%]
# Epoch [140], Training loss [0.0920], Training accuracy [96.97%]
# Epoch [140], Validation loss [1.7800], Validation accuracy [53.03%]
# Epoch [150], Training loss [0.0659], Training accuracy [97.98%]
# Epoch [150], Validation loss [1.7716], Validation accuracy [54.36%]
# Epoch [160], Training loss [0.0600], Training accuracy [97.98%]
# Epoch [160], Validation loss [1.8088], Validation accuracy [54.55%]
# Epoch [170], Training loss [0.0617], Training accuracy [98.17%]
# Epoch [170], Validation loss [1.8830], Validation accuracy [52.65%]
# Epoch [180], Training loss [0.0489], Training accuracy [98.65%]
# Epoch [180], Validation loss [1.7754], Validation accuracy [56.63%]
# Epoch [190], Training loss [0.0405], Training accuracy [98.70%]
# Epoch [190], Validation loss [1.7618], Validation accuracy [56.63%]
# Epoch [200], Training loss [0.0481], Training accuracy [98.46%]
# Epoch [200], Validation loss [1.7757], Validation accuracy [55.49%]
# Test accuracy [60.36%]
# Test accuracy from the best model during fold [1] is: [60.36%]
# Average test accuracy of 5-fold validation: [12.07]

# %% [markdown]
# # Conv2, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = Conv2(dropout=0.5).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3811], Training accuracy [31.79%]
# Epoch [10], Validation loss [1.3853], Validation accuracy [35.04%]
# Epoch [20], Training loss [1.3566], Training accuracy [40.26%]
# Epoch [20], Validation loss [1.3671], Validation accuracy [38.07%]
# Epoch [30], Training loss [1.0830], Training accuracy [54.02%]
# Epoch [30], Validation loss [1.2471], Validation accuracy [41.48%]
# Epoch [40], Training loss [0.8762], Training accuracy [63.20%]
# Epoch [40], Validation loss [1.0055], Validation accuracy [54.73%]
# Epoch [50], Training loss [0.7642], Training accuracy [69.12%]
# Epoch [50], Validation loss [0.9217], Validation accuracy [60.42%]
# Epoch [60], Training loss [0.6761], Training accuracy [72.68%]
# Epoch [60], Validation loss [0.8655], Validation accuracy [63.07%]
# Epoch [70], Training loss [0.6138], Training accuracy [75.61%]
# Epoch [70], Validation loss [0.7743], Validation accuracy [64.96%]
# Epoch [80], Training loss [0.5225], Training accuracy [81.05%]
# Epoch [80], Validation loss [0.7261], Validation accuracy [66.48%]
# Epoch [90], Training loss [0.4747], Training accuracy [82.54%]
# Epoch [90], Validation loss [0.7204], Validation accuracy [67.99%]
# Epoch [100], Training loss [0.4314], Training accuracy [83.98%]
# Epoch [100], Validation loss [0.7336], Validation accuracy [69.70%]
# Epoch [110], Training loss [0.4036], Training accuracy [85.43%]
# Epoch [110], Validation loss [0.7217], Validation accuracy [71.40%]
# Epoch [120], Training loss [0.3361], Training accuracy [89.37%]
# Epoch [120], Validation loss [0.6466], Validation accuracy [76.14%]
# Epoch [130], Training loss [0.3108], Training accuracy [90.14%]
# Epoch [130], Validation loss [0.6110], Validation accuracy [77.27%]
# Epoch [140], Training loss [0.2883], Training accuracy [90.62%]
# Epoch [140], Validation loss [0.6449], Validation accuracy [77.84%]
# Epoch [150], Training loss [0.2674], Training accuracy [91.39%]
# Epoch [150], Validation loss [0.6729], Validation accuracy [75.76%]
# Epoch [160], Training loss [0.2514], Training accuracy [92.16%]
# Epoch [160], Validation loss [0.6386], Validation accuracy [77.08%]
# Epoch [170], Training loss [0.2117], Training accuracy [93.80%]
# Epoch [170], Validation loss [0.6673], Validation accuracy [78.03%]
# Epoch [180], Training loss [0.2204], Training accuracy [93.22%]
# Epoch [180], Validation loss [0.6948], Validation accuracy [75.57%]
# Epoch [190], Training loss [0.1918], Training accuracy [94.23%]
# Epoch [190], Validation loss [0.7576], Validation accuracy [71.97%]
# Epoch [200], Training loss [0.1765], Training accuracy [94.85%]
# Epoch [200], Validation loss [0.6557], Validation accuracy [76.89%]
# Test accuracy [66.36%]
# Test accuracy from the best model during fold [1] is: [66.36%]
# Average test accuracy of 5-fold validation: [13.27]
