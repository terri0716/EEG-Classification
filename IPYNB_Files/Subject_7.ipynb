# %% [markdown]
# Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd '/content/drive/My Drive/Colab Notebooks/c247'

from all_models import *
from all_solvers import *
from all_functions import *

import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
from sklearn.model_selection import KFold
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
device = torch.device('cuda' if torch.cuda.is_available() else'cpu')
# Out:
# /content/drive/My Drive/Colab Notebooks/c247

# %% [markdown]
# Load Data

# %%
# subject data
subject = 7
X_test, y_test, X_train_valid, y_train_valid = import_data_subject(subject)

# %% [markdown]
# # DeepConv, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = DeepConv(in_channels=1, classes=4, cnn_drop=0.5, trial_length=window_width).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.1273], Training accuracy [49.52%]
# Epoch [10], Validation loss [1.8196], Validation accuracy [30.49%]
# Epoch [20], Training loss [0.7313], Training accuracy [71.67%]
# Epoch [20], Validation loss [2.1368], Validation accuracy [46.02%]
# Epoch [30], Training loss [0.5238], Training accuracy [80.33%]
# Epoch [30], Validation loss [2.3689], Validation accuracy [49.24%]
# Epoch [40], Training loss [0.3947], Training accuracy [85.55%]
# Epoch [40], Validation loss [2.7007], Validation accuracy [45.83%]
# Epoch [50], Training loss [0.2887], Training accuracy [89.38%]
# Epoch [50], Validation loss [2.9666], Validation accuracy [46.02%]
# Epoch [60], Training loss [0.2338], Training accuracy [91.77%]
# Epoch [60], Validation loss [3.1674], Validation accuracy [45.64%]
# Epoch [70], Training loss [0.1989], Training accuracy [93.68%]
# Epoch [70], Validation loss [3.1947], Validation accuracy [46.02%]
# Epoch [80], Training loss [0.1856], Training accuracy [93.35%]
# Epoch [80], Validation loss [3.4160], Validation accuracy [47.16%]
# Epoch [90], Training loss [0.1383], Training accuracy [95.79%]
# Epoch [90], Validation loss [3.5682], Validation accuracy [46.21%]
# Epoch [100], Training loss [0.1221], Training accuracy [96.32%]
# Epoch [100], Validation loss [3.5757], Validation accuracy [47.73%]
# Epoch [110], Training loss [0.1000], Training accuracy [97.03%]
# Epoch [110], Validation loss [3.8062], Validation accuracy [47.73%]
# Epoch [120], Training loss [0.0849], Training accuracy [97.75%]
# Epoch [120], Validation loss [3.7697], Validation accuracy [48.11%]
# Epoch [130], Training loss [0.0760], Training accuracy [97.85%]
# Epoch [130], Validation loss [3.8267], Validation accuracy [48.86%]
# Epoch [140], Training loss [0.0709], Training accuracy [98.37%]
# Epoch [140], Validation loss [3.8596], Validation accuracy [48.11%]
# Epoch [150], Training loss [0.0543], Training accuracy [98.76%]
# Epoch [150], Validation loss [4.0062], Validation accuracy [47.92%]
# Epoch [160], Training loss [0.0516], Training accuracy [99.04%]
# Epoch [160], Validation loss [4.0962], Validation accuracy [45.27%]
# Epoch [170], Training loss [0.0523], Training accuracy [98.95%]
# Epoch [170], Validation loss [4.0126], Validation accuracy [47.92%]
# Epoch [180], Training loss [0.0387], Training accuracy [99.14%]
# Epoch [180], Validation loss [3.9539], Validation accuracy [48.30%]
# Epoch [190], Training loss [0.0453], Training accuracy [98.66%]
# Epoch [190], Validation loss [4.0201], Validation accuracy [48.11%]
# Epoch [200], Training loss [0.0311], Training accuracy [99.38%]
# Epoch [200], Validation loss [4.0875], Validation accuracy [46.59%]
# Test accuracy [61.27%]
# Test accuracy from the best model during fold [1] is: [61.27%]
# Average test accuracy of 5-fold validation: [12.25]

# %% [markdown]
# # DeepConv2, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = DeepConv2(in_channels=1, classes=4, cnn_drop=0.5).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3731], Training accuracy [32.20%]
# Epoch [10], Validation loss [1.3743], Validation accuracy [33.33%]
# Epoch [20], Training loss [1.2262], Training accuracy [47.13%]
# Epoch [20], Validation loss [1.3951], Validation accuracy [33.33%]
# Epoch [30], Training loss [1.0223], Training accuracy [55.17%]
# Epoch [30], Validation loss [1.4533], Validation accuracy [33.33%]
# Epoch [40], Training loss [0.8321], Training accuracy [67.13%]
# Epoch [40], Validation loss [1.3912], Validation accuracy [33.52%]
# Epoch [50], Training loss [0.6606], Training accuracy [74.98%]
# Epoch [50], Validation loss [1.5245], Validation accuracy [32.01%]
# Epoch [60], Training loss [0.5333], Training accuracy [81.10%]
# Epoch [60], Validation loss [1.7303], Validation accuracy [27.08%]
# Epoch [70], Training loss [0.4140], Training accuracy [86.60%]
# Epoch [70], Validation loss [1.9267], Validation accuracy [27.08%]
# Epoch [80], Training loss [0.3536], Training accuracy [88.37%]
# Epoch [80], Validation loss [2.1055], Validation accuracy [28.79%]
# Epoch [90], Training loss [0.2578], Training accuracy [92.25%]
# Epoch [90], Validation loss [2.3840], Validation accuracy [26.52%]
# Epoch [100], Training loss [0.2291], Training accuracy [93.35%]
# Epoch [100], Validation loss [2.5215], Validation accuracy [28.79%]
# Epoch [110], Training loss [0.1424], Training accuracy [96.51%]
# Epoch [110], Validation loss [2.6367], Validation accuracy [30.30%]
# Epoch [120], Training loss [0.1163], Training accuracy [97.27%]
# Epoch [120], Validation loss [2.7142], Validation accuracy [32.39%]
# Epoch [130], Training loss [0.0925], Training accuracy [97.80%]
# Epoch [130], Validation loss [2.8280], Validation accuracy [32.20%]
# Epoch [140], Training loss [0.0877], Training accuracy [97.99%]
# Epoch [140], Validation loss [2.8562], Validation accuracy [33.71%]
# Epoch [150], Training loss [0.0721], Training accuracy [98.28%]
# Epoch [150], Validation loss [2.9765], Validation accuracy [32.58%]
# Epoch [160], Training loss [0.0659], Training accuracy [98.47%]
# Epoch [160], Validation loss [3.0514], Validation accuracy [32.77%]
# Epoch [170], Training loss [0.0614], Training accuracy [98.66%]
# Epoch [170], Validation loss [2.9952], Validation accuracy [35.23%]
# Epoch [180], Training loss [0.0479], Training accuracy [99.09%]
# Epoch [180], Validation loss [3.0295], Validation accuracy [34.85%]
# Epoch [190], Training loss [0.0401], Training accuracy [99.23%]
# Epoch [190], Validation loss [3.0403], Validation accuracy [35.80%]
# Epoch [200], Training loss [0.0367], Training accuracy [99.28%]
# Epoch [200], Validation loss [3.0668], Validation accuracy [35.80%]
# Test accuracy [46.73%]
# Test accuracy from the best model during fold [1] is: [46.73%]
# Average test accuracy of 5-fold validation: [9.35]

# %% [markdown]
# # Conv1, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = Conv1(dropout=0.5, trial_length=window_width).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.2376], Training accuracy [43.11%]
# Epoch [10], Validation loss [1.6241], Validation accuracy [26.33%]
# Epoch [20], Training loss [1.0163], Training accuracy [56.75%]
# Epoch [20], Validation loss [1.8565], Validation accuracy [30.49%]
# Epoch [30], Training loss [0.7610], Training accuracy [68.80%]
# Epoch [30], Validation loss [2.0727], Validation accuracy [31.25%]
# Epoch [40], Training loss [0.5777], Training accuracy [78.33%]
# Epoch [40], Validation loss [2.0962], Validation accuracy [36.36%]
# Epoch [50], Training loss [0.4176], Training accuracy [85.07%]
# Epoch [50], Validation loss [2.0376], Validation accuracy [47.35%]
# Epoch [60], Training loss [0.3090], Training accuracy [89.38%]
# Epoch [60], Validation loss [2.0596], Validation accuracy [52.84%]
# Epoch [70], Training loss [0.2396], Training accuracy [91.58%]
# Epoch [70], Validation loss [2.1868], Validation accuracy [54.73%]
# Epoch [80], Training loss [0.1721], Training accuracy [94.50%]
# Epoch [80], Validation loss [1.9479], Validation accuracy [61.17%]
# Epoch [90], Training loss [0.1490], Training accuracy [95.41%]
# Epoch [90], Validation loss [2.1084], Validation accuracy [59.85%]
# Epoch [100], Training loss [0.1077], Training accuracy [96.79%]
# Epoch [100], Validation loss [2.1550], Validation accuracy [56.63%]
# Epoch [110], Training loss [0.1021], Training accuracy [96.79%]
# Epoch [110], Validation loss [2.0498], Validation accuracy [61.17%]
# Epoch [120], Training loss [0.0902], Training accuracy [97.08%]
# Epoch [120], Validation loss [2.0029], Validation accuracy [59.66%]
# Epoch [130], Training loss [0.0644], Training accuracy [98.09%]
# Epoch [130], Validation loss [1.8732], Validation accuracy [61.74%]
# Epoch [140], Training loss [0.0544], Training accuracy [98.61%]
# Epoch [140], Validation loss [1.8848], Validation accuracy [63.26%]
# Epoch [150], Training loss [0.0458], Training accuracy [98.95%]
# Epoch [150], Validation loss [1.8562], Validation accuracy [63.83%]
# Epoch [160], Training loss [0.0356], Training accuracy [99.19%]
# Epoch [160], Validation loss [1.7770], Validation accuracy [64.39%]
# Epoch [170], Training loss [0.0351], Training accuracy [99.19%]
# Epoch [170], Validation loss [1.8095], Validation accuracy [65.34%]
# Epoch [180], Training loss [0.0324], Training accuracy [99.14%]
# Epoch [180], Validation loss [1.7283], Validation accuracy [66.29%]
# Epoch [190], Training loss [0.0245], Training accuracy [99.67%]
# Epoch [190], Validation loss [1.7863], Validation accuracy [65.53%]
# Epoch [200], Training loss [0.0245], Training accuracy [99.33%]
# Epoch [200], Validation loss [1.6388], Validation accuracy [67.80%]
# Test accuracy [73.09%]
# Test accuracy from the best model during fold [1] is: [73.09%]
# Average test accuracy of 5-fold validation: [14.62]

# %% [markdown]
# # Conv2, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = Conv2(dropout=0.5).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3758], Training accuracy [30.19%]
# Epoch [10], Validation loss [1.3876], Validation accuracy [25.95%]
# Epoch [20], Training loss [1.3190], Training accuracy [40.33%]
# Epoch [20], Validation loss [1.3750], Validation accuracy [28.60%]
# Epoch [30], Training loss [1.1489], Training accuracy [48.66%]
# Epoch [30], Validation loss [1.3160], Validation accuracy [32.58%]
# Epoch [40], Training loss [0.9809], Training accuracy [56.60%]
# Epoch [40], Validation loss [1.1518], Validation accuracy [39.58%]
# Epoch [50], Training loss [0.8529], Training accuracy [64.59%]
# Epoch [50], Validation loss [1.1632], Validation accuracy [40.34%]
# Epoch [60], Training loss [0.7212], Training accuracy [70.96%]
# Epoch [60], Validation loss [1.1951], Validation accuracy [42.42%]
# Epoch [70], Training loss [0.5980], Training accuracy [77.75%]
# Epoch [70], Validation loss [1.0879], Validation accuracy [54.17%]
# Epoch [80], Training loss [0.4651], Training accuracy [84.50%]
# Epoch [80], Validation loss [1.1213], Validation accuracy [55.87%]
# Epoch [90], Training loss [0.3927], Training accuracy [87.42%]
# Epoch [90], Validation loss [1.0283], Validation accuracy [61.36%]
# Epoch [100], Training loss [0.3175], Training accuracy [89.90%]
# Epoch [100], Validation loss [0.8238], Validation accuracy [71.97%]
# Epoch [110], Training loss [0.2749], Training accuracy [91.67%]
# Epoch [110], Validation loss [0.7451], Validation accuracy [75.57%]
# Epoch [120], Training loss [0.2078], Training accuracy [94.55%]
# Epoch [120], Validation loss [0.7966], Validation accuracy [71.02%]
# Epoch [130], Training loss [0.1984], Training accuracy [94.31%]
# Epoch [130], Validation loss [0.7459], Validation accuracy [75.38%]
# Epoch [140], Training loss [0.1749], Training accuracy [94.83%]
# Epoch [140], Validation loss [0.7038], Validation accuracy [77.27%]
# Epoch [150], Training loss [0.1383], Training accuracy [96.32%]
# Epoch [150], Validation loss [0.6314], Validation accuracy [80.68%]
# Epoch [160], Training loss [0.1307], Training accuracy [96.36%]
# Epoch [160], Validation loss [0.6752], Validation accuracy [77.46%]
# Epoch [170], Training loss [0.1021], Training accuracy [97.89%]
# Epoch [170], Validation loss [0.6638], Validation accuracy [76.70%]
# Epoch [180], Training loss [0.1058], Training accuracy [97.08%]
# Epoch [180], Validation loss [0.6181], Validation accuracy [80.49%]
# Epoch [190], Training loss [0.0912], Training accuracy [97.75%]
# Epoch [190], Validation loss [0.6597], Validation accuracy [79.36%]
# Epoch [200], Training loss [0.0849], Training accuracy [97.80%]
# Epoch [200], Validation loss [0.6849], Validation accuracy [78.41%]
# Test accuracy [77.45%]
# Test accuracy from the best model during fold [1] is: [77.45%]
# Average test accuracy of 5-fold validation: [15.49]
