# %% [markdown]
# Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
% cd '/content/drive/My Drive/Colab Notebooks/c247'

from all_models import *
from all_solvers import *
from all_functions import *

import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
from sklearn.model_selection import KFold
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
device = torch.device('cuda' if torch.cuda.is_available() else'cpu')
# Out:
# /content/drive/My Drive/Colab Notebooks/c247

# %% [markdown]
# Load Data

# %%
# subject data
subject = 5
X_test, y_test, X_train_valid, y_train_valid = import_data_subject(subject)

# %% [markdown]
# # DeepConv, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = DeepConv(in_channels=1, classes=4, cnn_drop=0.5, trial_length=window_width).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.2516], Training accuracy [43.04%]
# Epoch [10], Validation loss [1.3243], Validation accuracy [34.04%]
# Epoch [20], Training loss [0.9716], Training accuracy [62.77%]
# Epoch [20], Validation loss [1.1378], Validation accuracy [49.90%]
# Epoch [30], Training loss [0.7318], Training accuracy [72.00%]
# Epoch [30], Validation loss [1.0711], Validation accuracy [52.61%]
# Epoch [40], Training loss [0.5696], Training accuracy [78.14%]
# Epoch [40], Validation loss [1.0708], Validation accuracy [57.06%]
# Epoch [50], Training loss [0.4804], Training accuracy [81.91%]
# Epoch [50], Validation loss [1.1948], Validation accuracy [53.19%]
# Epoch [60], Training loss [0.3887], Training accuracy [86.65%]
# Epoch [60], Validation loss [1.3060], Validation accuracy [53.77%]
# Epoch [70], Training loss [0.3314], Training accuracy [89.02%]
# Epoch [70], Validation loss [1.4535], Validation accuracy [53.19%]
# Epoch [80], Training loss [0.2754], Training accuracy [91.78%]
# Epoch [80], Validation loss [1.5815], Validation accuracy [51.64%]
# Epoch [90], Training loss [0.2571], Training accuracy [91.34%]
# Epoch [90], Validation loss [1.6272], Validation accuracy [54.74%]
# Epoch [100], Training loss [0.2088], Training accuracy [93.57%]
# Epoch [100], Validation loss [1.6795], Validation accuracy [54.16%]
# Epoch [110], Training loss [0.1818], Training accuracy [94.97%]
# Epoch [110], Validation loss [1.6432], Validation accuracy [53.77%]
# Epoch [120], Training loss [0.1651], Training accuracy [95.12%]
# Epoch [120], Validation loss [1.7054], Validation accuracy [51.26%]
# Epoch [130], Training loss [0.1443], Training accuracy [95.50%]
# Epoch [130], Validation loss [1.7516], Validation accuracy [53.00%]
# Epoch [140], Training loss [0.1352], Training accuracy [95.99%]
# Epoch [140], Validation loss [1.8232], Validation accuracy [52.03%]
# Epoch [150], Training loss [0.1040], Training accuracy [97.20%]
# Epoch [150], Validation loss [1.7932], Validation accuracy [52.61%]
# Epoch [160], Training loss [0.1061], Training accuracy [96.81%]
# Epoch [160], Validation loss [1.8264], Validation accuracy [51.84%]
# Epoch [170], Training loss [0.0896], Training accuracy [97.92%]
# Epoch [170], Validation loss [1.8803], Validation accuracy [52.03%]
# Epoch [180], Training loss [0.0840], Training accuracy [98.02%]
# Epoch [180], Validation loss [1.8416], Validation accuracy [52.03%]
# Epoch [190], Training loss [0.0709], Training accuracy [98.21%]
# Epoch [190], Validation loss [1.9553], Validation accuracy [50.10%]
# Epoch [200], Training loss [0.0688], Training accuracy [98.31%]
# Epoch [200], Validation loss [1.8956], Validation accuracy [52.42%]
# Test accuracy [63.44%]
# Test accuracy from the best model during fold [1] is: [63.44%]
# Average test accuracy of 5-fold validation: [12.69]

# %% [markdown]
# # DeepConv2, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = DeepConv2(in_channels=1, classes=4, cnn_drop=0.5).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3827], Training accuracy [28.19%]
# Epoch [10], Validation loss [1.3948], Validation accuracy [17.02%]
# Epoch [20], Training loss [1.3782], Training accuracy [28.82%]
# Epoch [20], Validation loss [1.3984], Validation accuracy [17.02%]
# Epoch [30], Training loss [1.3311], Training accuracy [39.26%]
# Epoch [30], Validation loss [1.4396], Validation accuracy [17.02%]
# Epoch [40], Training loss [1.1167], Training accuracy [47.68%]
# Epoch [40], Validation loss [1.6700], Validation accuracy [20.70%]
# Epoch [50], Training loss [0.9806], Training accuracy [54.26%]
# Epoch [50], Validation loss [1.6581], Validation accuracy [17.60%]
# Epoch [60], Training loss [0.8351], Training accuracy [61.94%]
# Epoch [60], Validation loss [1.5471], Validation accuracy [34.62%]
# Epoch [70], Training loss [0.7030], Training accuracy [71.76%]
# Epoch [70], Validation loss [1.2599], Validation accuracy [46.62%]
# Epoch [80], Training loss [0.5680], Training accuracy [79.16%]
# Epoch [80], Validation loss [1.3702], Validation accuracy [51.06%]
# Epoch [90], Training loss [0.4061], Training accuracy [87.19%]
# Epoch [90], Validation loss [1.3798], Validation accuracy [51.84%]
# Epoch [100], Training loss [0.3054], Training accuracy [91.10%]
# Epoch [100], Validation loss [1.4200], Validation accuracy [52.22%]
# Epoch [110], Training loss [0.2515], Training accuracy [92.31%]
# Epoch [110], Validation loss [1.3600], Validation accuracy [55.71%]
# Epoch [120], Training loss [0.2192], Training accuracy [93.23%]
# Epoch [120], Validation loss [1.4777], Validation accuracy [52.80%]
# Epoch [130], Training loss [0.1912], Training accuracy [93.91%]
# Epoch [130], Validation loss [1.6207], Validation accuracy [50.10%]
# Epoch [140], Training loss [0.1543], Training accuracy [95.50%]
# Epoch [140], Validation loss [1.6279], Validation accuracy [49.90%]
# Epoch [150], Training loss [0.1443], Training accuracy [95.99%]
# Epoch [150], Validation loss [1.7368], Validation accuracy [45.07%]
# Epoch [160], Training loss [0.1203], Training accuracy [96.52%]
# Epoch [160], Validation loss [1.7245], Validation accuracy [47.20%]
# Epoch [170], Training loss [0.1224], Training accuracy [96.62%]
# Epoch [170], Validation loss [1.7579], Validation accuracy [49.71%]
# Epoch [180], Training loss [0.0876], Training accuracy [97.68%]
# Epoch [180], Validation loss [1.7863], Validation accuracy [49.90%]
# Epoch [190], Training loss [0.0933], Training accuracy [97.34%]
# Epoch [190], Validation loss [1.8720], Validation accuracy [45.45%]
# Epoch [200], Training loss [0.0758], Training accuracy [98.02%]
# Epoch [200], Validation loss [1.7620], Validation accuracy [51.64%]
# Test accuracy [60.93%]
# Test accuracy from the best model during fold [1] is: [60.93%]
# Average test accuracy of 5-fold validation: [12.19]

# %% [markdown]
# # Conv1, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = Conv1(dropout=0.5, trial_length=window_width).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3020], Training accuracy [38.73%]
# Epoch [10], Validation loss [1.3640], Validation accuracy [36.17%]
# Epoch [20], Training loss [1.1423], Training accuracy [49.08%]
# Epoch [20], Validation loss [1.2926], Validation accuracy [42.94%]
# Epoch [30], Training loss [0.9432], Training accuracy [61.51%]
# Epoch [30], Validation loss [1.0961], Validation accuracy [58.61%]
# Epoch [40], Training loss [0.7101], Training accuracy [72.58%]
# Epoch [40], Validation loss [0.9151], Validation accuracy [64.02%]
# Epoch [50], Training loss [0.5382], Training accuracy [79.45%]
# Epoch [50], Validation loss [0.8276], Validation accuracy [70.41%]
# Epoch [60], Training loss [0.4290], Training accuracy [84.43%]
# Epoch [60], Validation loss [0.7942], Validation accuracy [73.69%]
# Epoch [70], Training loss [0.3270], Training accuracy [88.88%]
# Epoch [70], Validation loss [0.7916], Validation accuracy [72.34%]
# Epoch [80], Training loss [0.2615], Training accuracy [91.20%]
# Epoch [80], Validation loss [0.8262], Validation accuracy [72.53%]
# Epoch [90], Training loss [0.2124], Training accuracy [93.04%]
# Epoch [90], Validation loss [0.8259], Validation accuracy [73.50%]
# Epoch [100], Training loss [0.1463], Training accuracy [95.55%]
# Epoch [100], Validation loss [0.8300], Validation accuracy [74.27%]
# Epoch [110], Training loss [0.1357], Training accuracy [95.65%]
# Epoch [110], Validation loss [0.8943], Validation accuracy [72.92%]
# Epoch [120], Training loss [0.1008], Training accuracy [97.10%]
# Epoch [120], Validation loss [0.8970], Validation accuracy [72.92%]
# Epoch [130], Training loss [0.0909], Training accuracy [97.68%]
# Epoch [130], Validation loss [0.9043], Validation accuracy [72.92%]
# Epoch [140], Training loss [0.0832], Training accuracy [97.68%]
# Epoch [140], Validation loss [0.9740], Validation accuracy [71.57%]
# Epoch [150], Training loss [0.0665], Training accuracy [98.11%]
# Epoch [150], Validation loss [0.9303], Validation accuracy [72.15%]
# Epoch [160], Training loss [0.0652], Training accuracy [97.97%]
# Epoch [160], Validation loss [0.9624], Validation accuracy [70.99%]
# Epoch [170], Training loss [0.0496], Training accuracy [98.79%]
# Epoch [170], Validation loss [0.9793], Validation accuracy [71.95%]
# Epoch [180], Training loss [0.0451], Training accuracy [99.03%]
# Epoch [180], Validation loss [0.9613], Validation accuracy [72.92%]
# Epoch [190], Training loss [0.0390], Training accuracy [98.94%]
# Epoch [190], Validation loss [0.9785], Validation accuracy [72.53%]
# Epoch [200], Training loss [0.0381], Training accuracy [99.27%]
# Epoch [200], Validation loss [1.0147], Validation accuracy [71.37%]
# Test accuracy [74.08%]
# Test accuracy from the best model during fold [1] is: [74.08%]
# Average test accuracy of 5-fold validation: [14.82]

# %% [markdown]
# # Conv2, trialsize 900, stride 10

# %%
# Set up cross validation folds, and average accuracy tracker
kf = KFold(n_splits=5, random_state=None, shuffle=True)
avg_accuracy=0
kcount = 1

for k_train_index, k_val_index in kf.split(X_train_valid):
  ## Only compute 1 fold due to computation time:
  if kcount==2:
    break
  ## Print fold
  print('-- Fold [{}/5] --'.format(kcount))

  ## Create this fold's dataloader
  SEGMENT = True
  VOTE = False
  window_width = 900
  stride = 10
  num_slices = int((1000-window_width)/stride+1)

  dataloaders = make_dataloaders(k_train_index, k_val_index, X_train_valid, y_train_valid, X_test, y_test, 
                                 cut=SEGMENT, window_width=window_width, stride=stride, num_slices=num_slices)
  
  ## Create model, hyperpatameters, optimizer, loss function 
  weight_decay = 0.001
  model = Conv2(dropout=0.5).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay=weight_decay)
  loss_fn = nn.CrossEntropyLoss()
  num_epochs = 200

  ## Start training/validating/training
  # set up per epoch accuracy and loss trackers
  loss_tracker = {'train':[], 'val':[]}
  accuracy_tracker = {'train':[], 'val':[]}
  best_model_params = [0, model]

  for epoch in range(num_epochs): 
    logs = {}
    # train on training samples
    model, epoch_loss_avg, epoch_accuracy = train(model, optimizer, loss_fn, dataloaders, device, epoch)
    loss_tracker['train'].append(epoch_loss_avg)
    accuracy_tracker['train'].append(epoch_accuracy)

    # evalutate on validation samples 
    epoch_loss_avg, epoch_accuracy, best_model_params = validate(model, optimizer, loss_fn, dataloaders, device, epoch, best_model_params)
    loss_tracker['val'].append(epoch_loss_avg)
    accuracy_tracker['val'].append(epoch_accuracy)

  # plot train/validation graph
  make_plot(num_epochs, loss_tracker, accuracy_tracker, saveplot=False)
  # get model weights from the epoch with the highest validation accuracy
  _, final_best_model = best_model_params
  thisacc = finaltest(final_best_model, dataloaders, device)
  print('Test accuracy from the best model during fold [{}] is: [{:.2f}%]'.format(kcount, thisacc))
  kcount += 1
  avg_accuracy += thisacc

print('Average test accuracy of 5-fold validation: [{:.2f}]'.format(avg_accuracy/5))
# Out:
# -- Fold [1/5] --
# Epoch [10], Training loss [1.3818], Training accuracy [30.56%]
# Epoch [10], Validation loss [1.3884], Validation accuracy [23.40%]
# Epoch [20], Training loss [1.3736], Training accuracy [32.45%]
# Epoch [20], Validation loss [1.3877], Validation accuracy [23.21%]
# Epoch [30], Training loss [1.3461], Training accuracy [36.51%]
# Epoch [30], Validation loss [1.3969], Validation accuracy [17.79%]
# Epoch [40], Training loss [1.2721], Training accuracy [43.13%]
# Epoch [40], Validation loss [1.4062], Validation accuracy [22.63%]
# Epoch [50], Training loss [1.1860], Training accuracy [48.74%]
# Epoch [50], Validation loss [1.4037], Validation accuracy [29.59%]
# Epoch [60], Training loss [1.0110], Training accuracy [60.11%]
# Epoch [60], Validation loss [1.3690], Validation accuracy [37.52%]
# Epoch [70], Training loss [0.8719], Training accuracy [66.49%]
# Epoch [70], Validation loss [1.2897], Validation accuracy [42.55%]
# Epoch [80], Training loss [0.7745], Training accuracy [70.89%]
# Epoch [80], Validation loss [1.2207], Validation accuracy [44.87%]
# Epoch [90], Training loss [0.6806], Training accuracy [75.34%]
# Epoch [90], Validation loss [1.1812], Validation accuracy [48.36%]
# Epoch [100], Training loss [0.6299], Training accuracy [77.37%]
# Epoch [100], Validation loss [1.1865], Validation accuracy [53.38%]
# Epoch [110], Training loss [0.5402], Training accuracy [81.24%]
# Epoch [110], Validation loss [1.1076], Validation accuracy [57.45%]
# Epoch [120], Training loss [0.5081], Training accuracy [82.11%]
# Epoch [120], Validation loss [1.1327], Validation accuracy [57.25%]
# Epoch [130], Training loss [0.4430], Training accuracy [84.62%]
# Epoch [130], Validation loss [1.0820], Validation accuracy [58.99%]
# Epoch [140], Training loss [0.4047], Training accuracy [86.17%]
# Epoch [140], Validation loss [1.1470], Validation accuracy [58.41%]
# Epoch [150], Training loss [0.3674], Training accuracy [87.86%]
# Epoch [150], Validation loss [1.0975], Validation accuracy [59.57%]
# Epoch [160], Training loss [0.3339], Training accuracy [88.30%]
# Epoch [160], Validation loss [1.0681], Validation accuracy [62.67%]
# Epoch [170], Training loss [0.3039], Training accuracy [89.51%]
# Epoch [170], Validation loss [1.0473], Validation accuracy [62.48%]
# Epoch [180], Training loss [0.2463], Training accuracy [92.60%]
# Epoch [180], Validation loss [1.0609], Validation accuracy [61.51%]
# Epoch [190], Training loss [0.2523], Training accuracy [92.31%]
# Epoch [190], Validation loss [1.0237], Validation accuracy [65.96%]
# Epoch [200], Training loss [0.2219], Training accuracy [93.62%]
# Epoch [200], Validation loss [1.0923], Validation accuracy [61.90%]
# Test accuracy [65.96%]
# Test accuracy from the best model during fold [1] is: [65.96%]
# Average test accuracy of 5-fold validation: [13.19]
